# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.width', 53)
pd.set_option('display.max_columns', 5)
pd.set_option('display.max_rows', 20)
pd.options.display.float_format = '{:,.1f}'.format

# %%
covidtotals = pd.read_csv("data/covidtotals.csv", parse_dates=['lastdate'])
covidtotals.set_index("iso_code", inplace=True)

# %%
covidtotals.shape
# Out:
# (231, 16)

# %%
covidtotals.sample(1, random_state=1).T
# Out:
# iso_code                         GHA
# lastdate         2023-12-03 00:00:00
# location                       Ghana
# total_cases                171,834.0
# total_deaths                 1,462.0
# total_cases_pm               5,133.1
# total_deaths_pm                 43.7
# population                  33475870
# pop_density                    126.7
# median_age                      21.1
# gdp_per_capita               4,227.6
# hosp_beds                        0.9
# vac_per_hund                     NaN
# aged_65_older                    3.4
# life_expectancy                 64.1
# hum_dev_ind                      0.6
# region                   West Africa

# %%
covidtotals.dtypes
# Out:
# lastdate           datetime64[ns]
# location                   object
# total_cases               float64
# total_deaths              float64
# total_cases_pm            float64
# total_deaths_pm           float64
# population                  int64
# pop_density               float64
# median_age                float64
# gdp_per_capita            float64
# hosp_beds                 float64
# vac_per_hund              float64
# aged_65_older             float64
# life_expectancy           float64
# hum_dev_ind               float64
# region                     object
# dtype: object

# %%
totvars = ['total_cases', 'total_deaths', 'total_cases_pm', 'total_deaths_pm']
covidtotals[totvars].describe()
# Out:
#         total_cases  total_deaths  total_cases_pm  \
# count         231.0         231.0           231.0
# mean    3,351,598.6      30,214.2       206,177.8
# std    11,483,211.8     104,778.9       203,858.1
# min             4.0           0.0           354.5
# 25%        25,671.5         177.5        21,821.9
# 50%       191,496.0       1,937.0       133,946.3
# 75%     1,294,286.0      14,150.0       345,689.8
# max   103,436,829.0   1,127,152.0       763,475.4
#
#        total_deaths_pm
# count            231.0
# mean           1,261.8
# std            1,315.0
# min                0.0
# 25%              141.2
# 50%              827.0
# 75%            1,997.5
# max            6,507.7

# %%
covidtotals[totvars].quantile(np.arange(0.0, 1.1, 0.1))
# Out:
#       total_cases  total_deaths  total_cases_pm  \
# 0.0           4.0           0.0           354.5
# 0.1       8,359.0          31.0         3,138.6
# 0.2      17,181.0         126.0        10,885.7
# 0.3      38,008.0         294.0        35,834.6
# 0.4      74,129.0         844.0        86,126.2
# 0.5     191,496.0       1,937.0       133,946.3
# 0.6     472,755.0       4,384.0       220,429.4
# 0.7   1,041,111.0       9,646.0       293,737.4
# 0.8   1,877,065.0      21,218.0       416,608.1
# 0.9   5,641,992.0      62,288.0       512,388.4
# 1.0 103,436,829.0   1,127,152.0       763,475.4
#
#      total_deaths_pm
# 0.0              0.0
# 0.1             32.9
# 0.2            105.3
# 0.3            210.5
# 0.4            498.8
# 0.5            827.0
# 0.6          1,251.3
# 0.7          1,697.6
# 0.8          2,271.7
# 0.9          3,155.9
# 1.0          6,507.7

# %%
covidtotals['total_cases']/1000
# Out:
# iso_code
# AFG      231.5
# ALB      334.9
# DZA      272.0
# ASM        8.4
# AND       48.0
#         ...
# VNM   11,624.0
# WLF        3.5
# YEM       11.9
# ZMB      349.3
# ZWE      266.3
# Name: total_cases, Length: 231, dtype: float64

# %%
plt.hist(covidtotals['total_cases']/1000, bins=12)
plt.title("Total COVID-19 Cases (in thousands)")
plt.xlabel("Cases")
plt.ylabel("Number of Countries")
plt.show()
